# %% [markdown]
# # **Project Name**    - **Hotel booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Name**    -  Chaitannya Uke

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The aim of this project is totally focus on Cancelled Bookings. To perform exploratory data analysis (EDA) on a hotel booking dataset in order to gain insights into customer behavior and booking patterns. The dataset contained information on hotel bookings, including booking dates, customer demographics, and reservation details. First, we cleaned and preprocessed the data, which involved removing missing values, handling duplicates. Then we visualized the data using various graphical techniques such as histograms, scatter plots, and heat maps. Through our analysis, we discovered several interesting insights. For example, we found that most bookings were made between july and August.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In recent Years, City and Resort hotels have seen high cancellations rates. Each hotel is now dealing with number of issues as a result, includiing fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates of both hotels, primary goal is to increase their efficiency in generating revenue, and for us to offer through  buisiness advice to address this problem.
#
# The analysis of hotel booking Cancellations as well as other factors that have no bearing on their buisiness and yearly revenue generation are the main topics of this project.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Lowering cancellation rates of both hotels, primary goal is to increase their efficiency in generating revenue, and for us to offer through  buisiness advice to address this problem.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Dataset loading
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Hotel Bookings.csv')

df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Last 5 Rows
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Converting data type of 'reservation_status_date' object to date
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
if 'company' in df.columns and 'agent' in df.columns:
    df.drop(['company', 'agent'], axis=1, inplace=True)                 # Colums having Null values are removed

# %%
df.dropna(inplace=True)                                                # Rows having Null values are removed

# %%
# Visualizing the missing values
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  86940.000000  86940.000000       86940.000000
# mean       0.275903     80.193375        2016.211824
# std        0.446971     86.100147           0.686016
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     12.000000        2016.000000
# 50%        0.000000     50.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              86940.000000               86940.000000
# mean                  26.841477                  15.818024
# std                   13.654505                   8.834469
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1.	hotel : Hotel(Resort Hotel or City Hotel)
# 2.	is_canceled : Value indicating if the booking was canceled (1) or not (0)
# 3.	lead_time :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
# 4.	arrival_date_year : Year of arrival date
# 5.	arrival_date_month : Month of arrival date
# 6.	arrival_date_week_number : Week number of year for arrival date
# 7.	arrival_date_day_of_month : Day of arrival date
# 8.	stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# 9.	stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# 10.	adults : Number of adults
# 11.	children : Number of children
# 12.	babies : Number of babies
# 13.	meal : Type of meal booked. Categories are presented in standard hospitality meal packages:
# 14.	country : Country of origin.`
# 15.	market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# 16.	distribution_channel : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# 17.	is_repeated_guest : Value indicating if the booking name was from a repeated guest (1) or not (0)
# 18.	previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
# 19.	previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
# 20.	reserved_room_type : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# 21.	assigned_room_type : Code for the type of room assigned to the booking.
# 22.	booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# 23.	deposit_type : Indication on if the customer made a deposit to guarantee the booking.
# 24.	agent : ID of the travel agency that made the booking
# 25.	company : ID of the company/entity that made the booking or responsible for paying the booking.
# 26.	days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
# 27.	customer_type : Type of booking, assuming one of four categories
# 28.	adr : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
# 29.	required_car_parking_spaces : Number of car parking spaces required by the customer
# 30.	total_of_special_requests :* Number of special requests made by the customer (e.g. twin bed or high floor)*
# 31.	reservation_status : Reservation last status, assuming one of three categories
# 32.	Canceled – booking was canceled by the customer
# 33.	Check-Out – customer has checked in but already departed
# 34.	No-Show – customer did not check-in and did inform the hotel of the reason why
# 35.	reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.describe(include='object')
# Out:
#              hotel arrival_date_month   meal country market_segment  \
# count        86940              86940  86940   86940          86940
# unique           2                 12      5     177              7
# top     City Hotel             August     BB     PRT      Online TA
# freq         53418              11232  67562   27449          51543
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 86940              86940              86940
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  69028              56189              46151
#
#        deposit_type customer_type reservation_status
# count         86940         86940              86940
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq          85796         71573              62953

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('_'*50)                     # to read each and eveery column seperatelty "-"
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# __________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# __________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# __________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
#  'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB' 'CMR'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df = df[df['adr']<5000]                                # remove outlier of "adr" - avg. daily rate less than 5000

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  86939.000000  86939.000000       86939.000000
# mean       0.275895     80.193895        2016.211827
# std        0.446967     86.100506           0.686019
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     12.000000        2016.000000
# 50%        0.000000     50.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              86939.000000               86939.000000
# mean                  26.841636                  15.817918
# std                   13.654503                   8.834465
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
cancelled_percent = df['is_canceled'].value_counts(normalize=True)
cancelled_percent
# Out:
# 0    0.724105
# 1    0.275895
# Name: is_canceled, dtype: float64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 62% Bookings are not cancelled but there are 37% bookings are cancelled Which is in big amount and which is the strongest factor for affecting the buissiness.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# **Reservation Staus Count**

# %%
# Chart - 1 visualization code
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(), width = 0.5)
plt.title('Reservation Staus Count')
# Out:
# Text(0.5, 1.0, 'Reservation Staus Count')

# %%
df['is_canceled'].value_counts().plot.pie(explode=[0.05,0.05],autopct='%1.1f%%',shadow=True, fontsize=10,labels=['Not cancelled', 'Canceled'])
plt.title('Cancellation and Non Cancelltion',fontsize=15)
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# The accompanying bar graph shows the percentage of reservation that are
# cancelled and those are not, it is obvious that there are still a significant number of reservations that have not been cancellled.
#
# There are still 30% of clients who cancelled their reservaations, which is significant impact on buisiness.

# %% [markdown]
# #### Chart - 2
# ***Cancellation of bookings according to Hotel***

# %%
# Chart - 2 visualization code
sns.countplot(x='hotel', hue = 'is_canceled', data=df)
plt.ylabel('Number of Bookings')
plt.title('Cancellation of bookings according to Hotel', size =15)
plt.legend(['not cancceled', 'canceled'])
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings.
#
# It is possible that Resort Hotels are Expensive than those are in cities .

# %% [markdown]
# #### Chart - 3
# **Average Daily Rate in City and Resort Hotel**

# %%
# Chart - 4 visualization code
Resort_hotel = df[df['hotel'] == 'Resort Hotel']
Resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.762962
# 1    0.237038
# Name: is_canceled, dtype: float64

# %%
City_hotel = df[df['hotel'] == 'City Hotel']
City_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.699721
# 1    0.300279
# Name: is_canceled, dtype: float64

# %%
Resort_hotel = Resort_hotel.groupby('reservation_status_date')[['adr']].mean()
City_hotel = City_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize = (20,8))
plt.plot(Resort_hotel.index,Resort_hotel['adr'])
plt.plot(City_hotel.index,City_hotel['adr'])
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.show()

# %% [markdown]
#  What is/are the insight(s) found from the chart?

# %% [markdown]
# The Line graph shows that, on cerrtain days , the average daily rate for a city hotel is less than resort hotels and On other days, it is even less .
#
# It goes without saying that weekends and holidays may see a rise in resort hotels rates .

# %% [markdown]
# #### Chart - 4
# **Reservation Status per Month according to cancellation**

# %%
# Chart - 5 visualization code

# %%
df['month'] = df['reservation_status_date'].dt.month
plt.figure(figsize=(20,8))
sns.countplot(x='month', hue = 'is_canceled', data=df)
plt.ylabel('Number of Reservation')
plt.title('Reservation Status per Month', size = 20)
plt.legend(['not cancceled', 'canceled'])
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# We  have developed the group bar chart to analyze the months with the highest and lowest reservaation levels according to reservation status.
#
# As we can see, both the cancelled and non cancelled reservations are largest in the August , whereas in January most of the booking cancellations are occured .

# %% [markdown]
# #### Chart - 5
# **ADR per Month**

# %%
plt.figure(figsize=(15,8))
RPM=df[df['is_canceled']==1].groupby('month')['adr'].sum().reset_index()
plt.bar(RPM['month'], RPM['adr'])
plt.title('ADR per Month', fontsize=20)
plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar graph demonstrates that cancellations are most common when prices are on highest side and leaset whenever the prices are lowest,  it clearly indicates that Price factor is strongly affected on bookings and cost of the accomodation is solely responsible for the cancellation.

# %% [markdown]
# #### Chart - 6
# **Cancellation Rate of Top 10 Countries**

# %%
# Chart - 7 visualization code
cancelled_data = df[df['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.pie(top_10_country,autopct='%.2f', labels = top_10_country.index)
plt.title('Top 10 Contries with reservation Cancelled')
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart shows the top 10 countries which has more number of cancellations.
#
# Frommm ghaph it clealy found that, Portugal is the at the top in case of bookings cancellations followed by Great Britain and least in Belgium.

# %% [markdown]
# #### Chart - 7
# **Cancellation Rate Vs Distribution channel**

# %%
canceled_df=df[df['is_canceled']==1] # 1= canceled
canceled_df=canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Bookings'})
canceled_df
sns.barplot(x='distribution_channel',y='Bookings',hue="hotel",data=canceled_df)
plt.title('Cancellation Rate Vs Distribution channel')
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# The Distribution channel TA/TO is most used channel for reservations and cancellations of hotel bookins .
#
# In "direct" both the hotels has almost same cancellation rate.

# %% [markdown]
# #### Chart - 08
# **Which Market Segment has the higest cancellation rate?**

# %%
market_segment_df=df[df['is_canceled']==1]   # canceled=1
market_segment_df
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by

market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      55
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     263
# 4       Corporate  Resort Hotel     234
# 5          Direct    City Hotel     911
# 6          Direct  Resort Hotel     812
# 7          Groups    City Hotel     890
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1259
# 10  Offline TA/TO  Resort Hotel     797
# 11      Online TA    City Hotel   12617
# 12      Online TA  Resort Hotel    5627

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)
plt.title('Cancellation Rate Vs market_segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs market_segment')

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# The Online TA Segment has the higest cancellation rate in both city as well as resort hotels.
#
# In order to reduce the booking cancellations hotels need to set the refundable/ no refundable and deposit policies policies

# %% [markdown]
# #### Chart - 09 - **Correlation Heatmap**

# %%
# Correlation Heatmap visualization code


plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True)
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# 1) is_canceled and same_room_alloted_or_not are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# 2) lead_time and total_stay is positively corelated.That means more is the stay of cutsomer more will be the lead time.
#
# 3)adults,childrens and babies are corelated to each other. That means more the people more will be adr.
#
# 4) is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# 1.   Cancellations rates rise as the price does, in order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates for specific hotels based on locations. Also can provide discounts when posssible.
# 2.   As the ratio of the cancellations and non cancellations of resort hotel is higher than city hotels.
# 3.   In January, hotels can start caampainings or marketings with reasonable amount to increase their revenue as tthe cancellations are high in January.
# 4.   They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.  The guests showed a preference for City hotels, making it the busiest type of hotel.
# 2. 27.5% of all bookings were cancelled.
# 3. About 79.1% of bookings were made through travel agents/tour operators.
# 4. More than 25,000 guests were from Portugal, making it the country with the highest number of guests.
# 5. City hotels generated more revenue than Resort hotels, with higher average ADR.
# 6. City hotels had a higher booking cancellation rate of almost 30%.
